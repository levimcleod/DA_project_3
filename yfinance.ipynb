# %%
import yfinance as yf
from pprint import pprint
from json import loads

msft = yf.Ticker("MSFT")
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
pprint(dict(msft.info))
# Out:
# {'SandP52WeekChange': -0.085127294,
#  'address1': 'One Microsoft Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 272.24,
#  'askSize': 2200,
#  'beta': 0.91562,
#  'beta3Year': None,
#  'bid': 272.2,
#  'bidSize': 1100,
#  'bookValue': 24.592,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Redmond',
#  'coinMarketCapLink': None,
#  'companyOfficers': [],
#  'country': 'United States',
#  'currentRatio': 1.931,
#  'dateShortInterest': 1675123200,
#  'debtToEquity': 42.583,
#  'dividendRate': 2.72,
#  'dividendYield': 0.010299999,
#  'earningsGrowth': -0.113,
#  'earningsQuarterlyGrowth': -0.125,
#  'ebitda': 97945001984,
#  'ebitdaMargins': 0.4799,
#  'enterpriseToEbitda': 19.776,
#  'enterpriseToRevenue': 9.491,
#  'enterpriseValue': 1936954753024,
#  'exDividendDate': 1676419200,
#  'expireDate': None,
#  'fax': '425 706 7329',
#  'financialCurrency': 'USD',
#  'fiveYearAverageReturn': None,
# ...
